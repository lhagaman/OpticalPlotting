# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Run 2 data

rho_mean_run2=[]
rho_min_run2=[]
rho_max_run2=[]
n_mean_run2=[]
n_min_run2=[]
n_max_run2=[]
gamma_mean_run2=[]
gamma_min_run2=[]
gamma_max_run2=[]
labels_run2=[]
labels_skived=[]

# LZ skived, low pressure
labels_run2.append("LZ skived, 0.2 barg")
labels_skived.append("4 0.2 barg")
rho_mean_run2.append(1.107)
rho_min_run2.append(1.101)
rho_max_run2.append(1.111)
n_mean_run2.append(1.554)
n_min_run2.append(1.548)
n_max_run2.append(1.556)
gamma_mean_run2.append(.102)
gamma_min_run2.append(.099)
gamma_max_run2.append(.108)

# LZ skived, low pressure #2
labels_run2.append("LZ skived, 0.2 barg #2")
labels_skived.append("7 0.2 barg #2")
rho_mean_run2.append(1.228)
rho_min_run2.append(1.2)
rho_max_run2.append(1.256)
n_mean_run2.append(1.55)
n_min_run2.append(1.549)
n_max_run2.append(1.551)
gamma_mean_run2.append(.132)
gamma_min_run2.append(.123)
gamma_max_run2.append(.14)

# LZ skived, med pressure
labels_run2.append("LZ skived, 0.9 barg")
labels_skived.append("5 0.9 barg")
rho_mean_run2.append(1.172)
rho_min_run2.append(1.171)
rho_max_run2.append(1.173)
n_mean_run2.append(1.562)
n_min_run2.append(1.561)
n_max_run2.append(1.563)
gamma_mean_run2.append(.107)
gamma_min_run2.append(.106)
gamma_max_run2.append(.108)

# LZ skived, med pressure #2
labels_run2.append("LZ skived, 0.9 barg #2")
labels_skived.append("8 0.9 barg #2")
rho_mean_run2.append(1.221)
rho_min_run2.append(1.211)
rho_max_run2.append(1.232)
n_mean_run2.append(1.563)
n_min_run2.append(1.556)
n_max_run2.append(1.57)
gamma_mean_run2.append(.136)
gamma_min_run2.append(.114)
gamma_max_run2.append(.157)

# LZ skived, high pressure
labels_run2.append("LZ skived, 1.4 barg")
labels_skived.append("6 1.4 barg")
rho_mean_run2.append(1.151)
rho_min_run2.append(1.148)
rho_max_run2.append(1.153)
n_mean_run2.append(1.569)
n_min_run2.append(1.569)
n_max_run2.append(1.57)
gamma_mean_run2.append(.113)
gamma_min_run2.append(.108)
gamma_max_run2.append(.118)

# LZ skived, high pressure #2
labels_run2.append("LZ skived, 1.4 barg #2")
labels_skived.append("9 1.4 barg #2")
rho_mean_run2.append(1.19)
rho_min_run2.append(1.149)
rho_max_run2.append(1.223)
n_mean_run2.append(1.551)
n_min_run2.append(1.545)
n_max_run2.append(1.561)
gamma_mean_run2.append(.177)
gamma_min_run2.append(.12)
gamma_max_run2.append(.208)

# LZ skived, 1/8" above center
labels_run2.append("LZ skived, 1/8\" up, 0.2 barg")
labels_skived.append("10 1/8\" up, 0.2 barg")
rho_mean_run2.append(1.246)
rho_min_run2.append(1.245)
rho_max_run2.append(1.247)
n_mean_run2.append(1.548)
n_min_run2.append(1.547)
n_max_run2.append(1.549)
gamma_mean_run2.append(.125)
gamma_min_run2.append(.124)
gamma_max_run2.append(.126)

# LZ skived, before getter, .39 barg
labels_run2.append("LZ skived, before getter")
labels_skived.append("2 before getter, 0.39 barg")
rho_mean_run2.append(1.159)
rho_min_run2.append(1.152)
rho_max_run2.append(1.171)
n_mean_run2.append(1.547)
n_min_run2.append(1.544)
n_max_run2.append(1.55)
gamma_mean_run2.append(.148)
gamma_min_run2.append(.123)
gamma_max_run2.append(.19)

# LZ skived, after getter, .39 barg
labels_run2.append("LZ skived, after getter")
labels_skived.append("3 after getter, 0.39 barg")
rho_mean_run2.append(1.15)
rho_min_run2.append(1.149)
rho_max_run2.append(1.151)
n_mean_run2.append(1.554)
n_min_run2.append(1.553)
n_max_run2.append(1.555)
gamma_mean_run2.append(.109)
gamma_min_run2.append(.108)
gamma_max_run2.append(.110)

# LZ skived, w/ bubbles, 1.0 barg
labels_run2.append("LZ skived, w/ bubbles")
labels_skived.append("1 w/ bubbles, 1.0 barg")
rho_mean_run2.append(1.116)
rho_min_run2.append(1.115)
rho_max_run2.append(1.117)
n_mean_run2.append(1.54)
n_min_run2.append(1.539)
n_max_run2.append(1.541)
gamma_mean_run2.append(.144)
gamma_min_run2.append(.143)
gamma_max_run2.append(.145)

# Copy over data for skived sample specifically
rho_mean_skived=rho_mean_run2[:]
rho_min_skived=rho_min_run2[:]
rho_max_skived=rho_max_run2[:]
n_mean_skived=n_mean_run2[:]
n_min_skived=n_min_run2[:]
n_max_skived=n_max_run2[:]
gamma_mean_skived=gamma_mean_run2[:]
gamma_min_skived=gamma_min_run2[:]
gamma_max_skived=gamma_max_run2[:]

# NXT85
labels_run2.append("NXT85")
rho_mean_run2.append(1.0945)
rho_min_run2.append(1.093)
rho_max_run2.append(1.096)
n_mean_run2.append(1.536)
n_min_run2.append(1.535)
n_max_run2.append(1.537)
gamma_mean_run2.append(.124)
gamma_min_run2.append(.117)
gamma_max_run2.append(.13)

# M18 polished
labels_run2.append("M18 polished")
rho_mean_run2.append(1.292)
rho_min_run2.append(1.285)
rho_max_run2.append(1.302)
n_mean_run2.append(1.548)
n_min_run2.append(1.545)
n_max_run2.append(1.55)
gamma_mean_run2.append(.057)
gamma_min_run2.append(.05)
gamma_max_run2.append(.082)

rho_mean_run2=np.array(rho_mean_run2)
rho_min_run2=np.array(rho_min_run2)
rho_max_run2=np.array(rho_max_run2)
n_mean_run2=np.array(n_mean_run2)
n_min_run2=np.array(n_min_run2)
n_max_run2=np.array(n_max_run2)
gamma_mean_run2=np.array(gamma_mean_run2)
gamma_min_run2=np.array(gamma_min_run2)
gamma_max_run2=np.array(gamma_max_run2)

rho_err_low_run2=rho_mean_run2-rho_min_run2
rho_err_hi_run2=rho_max_run2-rho_mean_run2
rho_errs_run2=np.vstack((rho_err_low_run2,rho_err_hi_run2))
n_err_low_run2=n_mean_run2-n_min_run2
n_err_hi_run2=n_max_run2-n_mean_run2
n_errs_run2=np.vstack((n_err_low_run2,n_err_hi_run2))
gamma_err_low_run2=gamma_mean_run2-gamma_min_run2
gamma_err_hi_run2=gamma_max_run2-gamma_mean_run2
gamma_errs_run2=np.vstack((gamma_err_low_run2,gamma_err_hi_run2))

# Run 1 data
rho_mean_run1=[]
rho_min_run1=[]
rho_max_run1=[]
n_mean_run1=[]
n_min_run1=[]
n_max_run1=[]
gamma_mean_run1=[]
gamma_min_run1=[]
gamma_max_run1=[]
labels_run1=[]

# LZ skived, no bubbles
labels_run1.append("LZ skived")
labels_skived.append("Run 1")
rho_mean_run1.append(.977)
rho_min_run1.append(.976)
rho_max_run1.append(.978)
n_mean_run1.append(1.55)
n_min_run1.append(1.545)
n_max_run1.append(1.555)
gamma_mean_run1.append(.105)
gamma_min_run1.append(.104)
gamma_max_run1.append(.106)

rho_mean_skived += rho_mean_run1
rho_min_skived += rho_min_run1
rho_max_skived += rho_max_run1
n_mean_skived += n_mean_run1
n_min_skived += n_min_run1
n_max_skived += n_max_run1
gamma_mean_skived += gamma_mean_run1
gamma_min_skived += gamma_min_run1
gamma_max_skived += gamma_max_run1

# M18 turn, no bubbles
labels_run1.append("M18 turn")
rho_mean_run1.append(.916)
rho_min_run1.append(.915)
rho_max_run1.append(.917)
n_mean_run1.append(1.54)
n_min_run1.append(1.535)
n_max_run1.append(1.545)
gamma_mean_run1.append(.192)
gamma_min_run1.append(.191)
gamma_max_run1.append(.193)

# Old sample, no bubbles
labels_run1.append("LUX")
rho_mean_run1.append(.774)
rho_min_run1.append(.773)
rho_max_run1.append(.775)
n_mean_run1.append(1.55)
n_min_run1.append(1.545)
n_max_run1.append(1.555)
gamma_mean_run1.append(.165)
gamma_min_run1.append(.164)
gamma_max_run1.append(.166)

rho_mean_run1=np.array(rho_mean_run1)
rho_min_run1=np.array(rho_min_run1)
rho_max_run1=np.array(rho_max_run1)
n_mean_run1=np.array(n_mean_run1)
n_min_run1=np.array(n_min_run1)
n_max_run1=np.array(n_max_run1)
gamma_mean_run1=np.array(gamma_mean_run1)
gamma_min_run1=np.array(gamma_min_run1)
gamma_max_run1=np.array(gamma_max_run1)

rho_err_low_run1=rho_mean_run1-rho_min_run1
rho_err_hi_run1=rho_max_run1-rho_mean_run1
rho_errs_run1=np.vstack((rho_err_low_run1,rho_err_hi_run1))
n_err_low_run1=n_mean_run1-n_min_run1
n_err_hi_run1=n_max_run1-n_mean_run1
n_errs_run1=np.vstack((n_err_low_run1,n_err_hi_run1))
gamma_err_low_run1=gamma_mean_run1-gamma_min_run1
gamma_err_hi_run1=gamma_max_run1-gamma_mean_run1
gamma_errs_run1=np.vstack((gamma_err_low_run1,gamma_err_hi_run1))

# Run 3 data

rho_mean_run3=[]
rho_min_run3=[]
rho_max_run3=[]
n_mean_run3=[]
n_min_run3=[]
n_max_run3=[]
gamma_mean_run3=[]
gamma_min_run3=[]
gamma_max_run3=[]
labels_run3=[]

# LZ skived, low pressure
labels_run3.append("LZ skived, 0.2 barg")
labels_skived.append("Run 3, 0.2 barg")
rho_mean_run3.append(1.01)
rho_min_run3.append(.946)
rho_max_run3.append(1.044)
n_mean_run3.append(1.542)
n_min_run3.append(1.532)
n_max_run3.append(1.547)
gamma_mean_run3.append(.1095)
gamma_min_run3.append(.107)
gamma_max_run3.append(.111)

# LZ skived, high pressure
labels_run3.append("LZ skived, 1.4 barg")
labels_skived.append("Run 3, 1.4 barg")
rho_mean_run3.append(1.136)
rho_min_run3.append(1.128)
rho_max_run3.append(1.148)
n_mean_run3.append(1.556)
n_min_run3.append(1.55)
n_max_run3.append(1.566)
gamma_mean_run3.append(.129)
gamma_min_run3.append(.122)
gamma_max_run3.append(.14)

rho_mean_skived += rho_mean_run3
rho_min_skived += rho_min_run3
rho_max_skived += rho_max_run3
n_mean_skived += n_mean_run3
n_min_skived += n_min_run3
n_max_skived += n_max_run3
gamma_mean_skived += gamma_mean_run3
gamma_min_skived += gamma_min_run3
gamma_max_skived += gamma_max_run3

rho_mean_skived=np.array(rho_mean_skived)
rho_min_skived=np.array(rho_min_skived)
rho_max_skived=np.array(rho_max_skived)
n_mean_skived=np.array(n_mean_skived)
n_min_skived=np.array(n_min_skived)
n_max_skived=np.array(n_max_skived)
gamma_mean_skived=np.array(gamma_mean_skived)
gamma_min_skived=np.array(gamma_min_skived)
gamma_max_skived=np.array(gamma_max_skived)

rho_err_low_skived=rho_mean_skived-rho_min_skived
rho_err_hi_skived=rho_max_skived-rho_mean_skived
rho_errs_skived=np.vstack((rho_err_low_skived,rho_err_hi_skived))
n_err_low_skived=n_mean_skived-n_min_skived
n_err_hi_skived=n_max_skived-n_mean_skived
n_errs_skived=np.vstack((n_err_low_skived,n_err_hi_skived))
gamma_err_low_skived=gamma_mean_skived-gamma_min_skived
gamma_err_hi_skived=gamma_max_skived-gamma_mean_skived
gamma_errs_skived=np.vstack((gamma_err_low_skived,gamma_err_hi_skived))

# 807NX, low pressure
labels_run3.append("807NX, 0.2 barg")
rho_mean_run3.append(1.043)
rho_min_run3.append(1.026)
rho_max_run3.append(1.055)
n_mean_run3.append(1.527)
n_min_run3.append(1.525)
n_max_run3.append(1.532)
gamma_mean_run3.append(.182)
gamma_min_run3.append(.14)
gamma_max_run3.append(.193)

# 807NX, high pressure
labels_run3.append("807NX, 1.4 barg")
rho_mean_run3.append(1.101)
rho_min_run3.append(1.077)
rho_max_run3.append(1.117)
n_mean_run3.append(1.545)
n_min_run3.append(1.543)
n_max_run3.append(1.546)
gamma_mean_run3.append(.214)
gamma_min_run3.append(.21)
gamma_max_run3.append(.22)

# M17 turn, low pressure
labels_run3.append("M17, 0.2 barg")
rho_mean_run3.append(.957)
rho_min_run3.append(.952)
rho_max_run3.append(.961)
n_mean_run3.append(1.516)
n_min_run3.append(1.513)
n_max_run3.append(1.519)
gamma_mean_run3.append(.211)
gamma_min_run3.append(.206)
gamma_max_run3.append(.215)

# M17 turn, low pressure, 1/8" above center
labels_run3.append("M17, 1/8\" up, 0.2 barg")
rho_mean_run3.append(1.086)
rho_min_run3.append(1.081)
rho_max_run3.append(1.09)
n_mean_run3.append(1.516)
n_min_run3.append(1.513)
n_max_run3.append(1.519)
gamma_mean_run3.append(.21)
gamma_min_run3.append(.208)
gamma_max_run3.append(.213)

# M17 turn, high pressure
labels_run3.append("M17, 1.4 barg")
rho_mean_run3.append(1.0735)
rho_min_run3.append(1.072)
rho_max_run3.append(1.075)
n_mean_run3.append(1.54)
n_min_run3.append(1.536)
n_max_run3.append(1.543)
gamma_mean_run3.append(.211)
gamma_min_run3.append(.205)
gamma_max_run3.append(.216)

rho_mean_run3=np.array(rho_mean_run3)
rho_min_run3=np.array(rho_min_run3)
rho_max_run3=np.array(rho_max_run3)
n_mean_run3=np.array(n_mean_run3)
n_min_run3=np.array(n_min_run3)
n_max_run3=np.array(n_max_run3)
gamma_mean_run3=np.array(gamma_mean_run3)
gamma_min_run3=np.array(gamma_min_run3)
gamma_max_run3=np.array(gamma_max_run3)

rho_err_low_run3=rho_mean_run3-rho_min_run3
rho_err_hi_run3=rho_max_run3-rho_mean_run3
rho_errs_run3=np.vstack((rho_err_low_run3,rho_err_hi_run3))
n_err_low_run3=n_mean_run3-n_min_run3
n_err_hi_run3=n_max_run3-n_mean_run3
n_errs_run3=np.vstack((n_err_low_run3,n_err_hi_run3))
gamma_err_low_run3=gamma_mean_run3-gamma_min_run3
gamma_err_hi_run3=gamma_max_run3-gamma_mean_run3
gamma_errs_run3=np.vstack((gamma_err_low_run3,gamma_err_hi_run3))

# print(labels_skived)

# %%
plt.figure(figsize=(10,5))
plt.errorbar(rho_mean_run1,n_mean_run1,xerr=rho_errs_run1,yerr=n_errs_run1,linestyle="",label="Run 1")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("n_PTFE")
#plt.xlim(0.9,1.32)
#plt.ylim(1.5,1.6)
for ii in range(len(labels_run1)):
    plt.text(rho_mean_run1[ii],n_mean_run1[ii]+.001,labels_run1[ii])

plt.figure(figsize=(10,5))
plt.errorbar(rho_mean_run1,gamma_mean_run1,xerr=rho_errs_run1,yerr=gamma_errs_run1,linestyle="",label="Run 1")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("gamma")
#plt.xlim(0.9,1.32)
#plt.ylim(0.04,0.25)
for ii in range(len(labels_run1)):
    plt.text(rho_mean_run1[ii],gamma_mean_run1[ii]+.005,labels_run1[ii])

# %%
plt.figure(figsize=(15,5))
plt.errorbar(rho_mean_skived,n_mean_skived,xerr=rho_errs_skived,yerr=n_errs_skived,linestyle="",label="LZ Skived")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("n_PTFE")
plt.xlim(0.95,1.27)
plt.ylim(1.53,1.58)
for ii in range(len(labels_skived)):
    plt.text(rho_mean_skived[ii],n_mean_skived[ii]+.003,labels_skived[ii])

plt.figure(figsize=(15,5))
plt.errorbar(rho_mean_skived,gamma_mean_skived,xerr=rho_errs_skived,yerr=gamma_errs_skived,linestyle="",label="LZ Skived")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("gamma")
plt.xlim(0.95,1.27)
plt.ylim(0.07,0.23)
for ii in range(len(labels_skived)):
    plt.text(rho_mean_skived[ii],gamma_mean_skived[ii]+.005,labels_skived[ii])

# %% [markdown]
# For a fixed pressure, this sample seems to show an increase in albedo w/ time. For a fixed time, there seems to be an increase in index w/ increasing pressure (aside from second 1.4 barg measurement). There may also be a slight increase in gamma w/ increasing pressure.

# %%
plt.figure(figsize=(10,5))
plt.errorbar(rho_mean_run2,n_mean_run2,xerr=rho_errs_run2,yerr=n_errs_run2,linestyle="",label="Run 2")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("n_PTFE")
plt.xlim(0.9,1.32)
plt.ylim(1.5,1.6)
for ii in range(len(labels_run2)):
    plt.text(rho_mean_run2[ii],n_mean_run2[ii]+.005,labels_run2[ii])

plt.figure(figsize=(10,5))
plt.errorbar(rho_mean_run2,gamma_mean_run2,xerr=rho_errs_run2,yerr=gamma_errs_run2,linestyle="",label="Run 2")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("gamma")
plt.xlim(0.9,1.32)
plt.ylim(0.04,0.25)
for ii in range(len(labels_run2)):
    plt.text(rho_mean_run2[ii],gamma_mean_run2[ii]+.005,labels_run2[ii])
    
    
plt.figure(figsize=(10,5))
plt.errorbar(rho_mean_run3,n_mean_run3,xerr=rho_errs_run3,yerr=n_errs_run3,linestyle="",label="Run 3")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("n_PTFE")
plt.xlim(0.9,1.32)
plt.ylim(1.5,1.6)
for ii in range(len(labels_run3)):
    plt.text(rho_mean_run3[ii],n_mean_run3[ii]+.005,labels_run3[ii])
    
plt.figure(figsize=(10,5))
plt.errorbar(rho_mean_run3,gamma_mean_run3,xerr=rho_errs_run3,yerr=gamma_errs_run3,linestyle="",label="Run 3")
plt.legend()
plt.xlabel("albedo")
plt.ylabel("gamma")
plt.xlim(0.9,1.32)
plt.ylim(0.04,0.25)
for ii in range(len(labels_run3)):
    plt.text(rho_mean_run3[ii],gamma_mean_run3[ii]+.005,labels_run3[ii])
